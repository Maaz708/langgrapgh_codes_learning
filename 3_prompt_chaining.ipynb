# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from typing import TypedDict
load_dotenv()
# Out:
# True

# %%
llm=ChatGroq(model='openai/gpt-oss-120b')

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState)-> BlogState:
    #fetch title
    title = state['title']

    #call llm generate outline

    prompt = f"Generate a  detailed outline for a blog on the topic - {title}"

    outline = llm.invoke(prompt).content

    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title=state['title']
    outline=state['outline']

    prompt = f'Write a detailed blog on the title -{title} using the following outline \n {outline}'

    content = llm.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)

graph.add_node('create_blog', create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initial_state={'title':'Transformer architecture'}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Transformer architecture', 'outline': '## Blog Outline: **Demystifying the Transformer Architecture**\n\n---\n\n### 1. Introduction  \n- **Hook** – Why Transformers have become the de‑facto standard for NLP (and beyond).  \n- **Brief History** – From “Attention Is All You Need” (Vaswani et\u202f2020) to today’s LLM boom.  \n- **What Readers Will Learn** – Core components, intuition behind each part, practical tips for implementation, and where the research is heading.\n\n---\n\n### 2. Foundations: Why We Needed Transformers  \n| Problem | Traditional Solution | Limitations |\n|---------|----------------------|-------------|\n| Sequential processing (RNNs/LSTMs) | Recurrence + hidden state | Vanishing gradients, limited parallelism |\n| Fixed‑size context windows | Convolutional nets | Local receptive fields |\n| Long‑range dependencies | Hand‑crafted features | Poor scalability |\n\n- **Key Insight:** *Self‑attention* replaces recurrence & convolution, enabling global context in a single layer.\n\n---\n\n### 3. Core Building Blocks  \n\n#### 3.1. Input Representation  \n- Tokenization (WordPiece, BPE, SentencePiece)  \n- Embedding lookup → **\\(X \\in \\mathbb{R}^{N \\times d_{model}}\\)**  \n- Adding **positional encodings** (sinusoidal vs. learned)\n\n#### 3.2. Scaled Dot‑Product Attention  \n- Formula: \\(\\text{Attention}(Q,K,V)=\\text{softmax}\\!\\big(\\frac{QK^\\top}{\\sqrt{d_k}}\\big)V\\)  \n- Intuition: “Query looks for similar keys, then gathers values.”  \n- **Visualization tip:** heat‑map of attention scores for a sample sentence.\n\n#### 3.3. Multi‑Head Attention  \n- Split \\(d_{model}\\) into \\(h\\) heads → parallel attention subspaces.  \n- Concatenation + final linear projection.  \n- Benefits: captures different relational patterns simultaneously.\n\n#### 3.4. Position‑wise Feed‑Forward Networks (FFN)  \n- Two linear layers with ReLU (or GELU) in between:  \n  \\(\\text{FFN}(x)=\\max(0, xW_1 + b_1)W_2 + b_2\\)  \n- Applied **identically** to each token → adds non‑linearity.\n\n#### 3.5. Residual Connections & Layer Normalization  \n- **Add & Norm** pattern after each sub‑layer (attention & FFN).  \n- Stabilizes training, enables deeper stacks.\n\n#### 3.6. Encoder vs. Decoder Stacks  \n| Encoder | Decoder |\n|--------|----------|\n| Stack of **self‑attention** + FFN | **Masked self‑attention** (prevents seeing future tokens) + **encoder‑decoder attention** + FFN |\n| Produces contextualized hidden states | Generates output autoregressively |\n\n- Diagram suggestion: side‑by‑side schematic of encoder and decoder layers.\n\n---\n\n### 4. Detailed Walkthrough of a Single Transformer Layer  \n\n1. **Input → Multi‑Head Self‑Attention**  \n   - Compute \\(Q,K,V\\) from the same source.  \n   - Apply mask (optional).  \n\n2. **Add & Norm** (Residual + LayerNorm).  \n\n3. **FFN** (position‑wise).  \n\n4. **Add & Norm** (second residual).  \n\n5. **Output** passed to next layer (or to decoder attention).\n\n- Include pseudo‑code snippet (PyTorch‑style) for clarity.\n\n---\n\n### 5. Positional Encoding Deep Dive  \n\n- **Sinusoidal formula**: \\(\\text{PE}_{(pos,2i)} = \\sin(pos/10000^{2i/d_{model}})\\)  \n- **Learned embeddings**: when to prefer them (e.g., vision Transformers).  \n- **Effect on model** – Show a small experiment: same sentence with/without positional info.\n\n---\n\n### 6. Training the Transformer  \n\n| Aspect | Typical Choices | Why It Matters |\n|--------|----------------|----------------|\n| Optimizer | AdamW (β₁=0.9, β₂=0.98) | Handles large LR warm‑up |\n| Learning‑rate schedule | **Warm‑up + inverse‑sqrt decay** | Prevents divergence early |\n| Regularization | Dropout (0.1), label smoothing (0.1) | Improves generalization |\n| Batch size & mixed‑precision | 32‑64\u202fGB GPUs, FP16 | Reduces memory, speeds up |\n| Gradient clipping | Norm ≤ 1.0 | Stabilizes training |\n\n- Provide a **training loop** skeleton with these components highlighted.\n\n---\n\n### 7. Variants & Extensions  ...

# %%
print(final_state['outline'])
# Out:
# ## Blog Outline: **Demystifying the Transformer Architecture**
#
# ---
#
# ### 1. Introduction
# - **Hook** – Why Transformers have become the de‑facto standard for NLP (and beyond).
# - **Brief History** – From “Attention Is All You Need” (Vaswani et 2020) to today’s LLM boom.
# - **What Readers Will Learn** – Core components, intuition behind each part, practical tips for implementation, and where the research is heading.
#
# ---
#
# ### 2. Foundations: Why We Needed Transformers
# | Problem | Traditional Solution | Limitations |
# |---------|----------------------|-------------|
# | Sequential processing (RNNs/LSTMs) | Recurrence + hidden state | Vanishing gradients, limited parallelism |
# | Fixed‑size context windows | Convolutional nets | Local receptive fields |
# | Long‑range dependencies | Hand‑crafted features | Poor scalability |
#
# - **Key Insight:** *Self‑attention* replaces recurrence & convolution, enabling global context in a single layer.
#
# ---
#
# ### 3. Core Building Blocks
#
# #### 3.1. Input Representation
# - Tokenization (WordPiece, BPE, SentencePiece)
# - Embedding lookup → **\(X \in \mathbb{R}^{N \times d_{model}}\)**
# - Adding **positional encodings** (sinusoidal vs. learned)
#
# #### 3.2. Scaled Dot‑Product Attention
# - Formula: \(\text{Attention}(Q,K,V)=\text{softmax}\!\big(\frac{QK^\top}{\sqrt{d_k}}\big)V\)
# - Intuition: “Query looks for similar keys, then gathers values.”
# - **Visualization tip:** heat‑map of attention scores for a sample sentence.
#
# #### 3.3. Multi‑Head Attention
# - Split \(d_{model}\) into \(h\) heads → parallel attention subspaces.
# - Concatenation + final linear projection.
# - Benefits: captures different relational patterns simultaneously.
#
# #### 3.4. Position‑wise Feed‑Forward Networks (FFN)
# - Two linear layers with ReLU (or GELU) in between:
#   \(\text{FFN}(x)=\max(0, xW_1 + b_1)W_2 + b_2\)
# - Applied **identically** to each token → adds non‑linearity.
#
# #### 3.5. Residual Connections & Layer Normalization
# - **Add & Norm** pattern after each sub‑layer (attention & FFN).
# - Stabilizes training, enables deeper stacks.
#
# #### 3.6. Encoder vs. Decoder Stacks
# | Encoder | Decoder |
# |--------|----------|
# | Stack of **self‑attention** + FFN | **Masked self‑attention** (prevents seeing future tokens) + **encoder‑decoder attention** + FFN |
# | Produces contextualized hidden states | Generates output autoregressively |
#
# - Diagram suggestion: side‑by‑side schematic of encoder and decoder layers.
#
# ---
#
# ### 4. Detailed Walkthrough of a Single Transformer Layer
#
# 1. **Input → Multi‑Head Self‑Attention**
#    - Compute \(Q,K,V\) from the same source.
#    - Apply mask (optional).
#
# 2. **Add & Norm** (Residual + LayerNorm).
#
# 3. **FFN** (position‑wise).
#
# 4. **Add & Norm** (second residual).
#
# 5. **Output** passed to next layer (or to decoder attention).
#
# - Include pseudo‑code snippet (PyTorch‑style) for clarity.
#
# ---
#
# ### 5. Positional Encoding Deep Dive
#
# - **Sinusoidal formula**: \(\text{PE}_{(pos,2i)} = \sin(pos/10000^{2i/d_{model}})\)
# - **Learned embeddings**: when to prefer them (e.g., vision Transformers).
# - **Effect on model** – Show a small experiment: same sentence with/without positional info.
#
# ---
#
# ### 6. Training the Transformer
#
# | Aspect | Typical Choices | Why It Matters |
# |--------|----------------|----------------|
# | Optimizer | AdamW (β₁=0.9, β₂=0.98) | Handles large LR warm‑up |
# | Learning‑rate schedule | **Warm‑up + inverse‑sqrt decay** | Prevents divergence early |
# | Regularization | Dropout (0.1), label smoothing (0.1) | Improves generalization |
# | Batch size & mixed‑precision | 32‑64 GB GPUs, FP16 | Reduces memory, speeds up |
# | Gradient clipping | Norm ≤ 1.0 | Stabilizes training |
#
# - Provide a **training loop** skeleton with these components highlighted.
#
# ---
#
# ### 7. Variants & Extensions
#
# | Variant | Main Modification | Typical Use‑Case |
# |---------|-------------------|------------------|
# | **BERT** | Encoder‑only, bidirectional, MLM + NSP | Pre‑training for downstream tasks |
# | **GPT** | Decoder‑only, causal LM | Autoregressive generation |
# | **RoBERTa** | Longer training, no NSP, larger batch | Better masked‑LM performance |
# | **Transformer‑XL** | Segment‑level recurrence, relative pos. enc. | Long‑context language modeling |
# | **Vision Transformer (ViT)** | Patch embedding + pure transformer | Image classification |
# | **Switch / Mixture‑of‑Experts** | Sparse routing, conditional computation | Scaling to trillion‑parameter models |
# | **Efficient Transformers** (Linformer, Performer, Reformer) | Approximate attention to reduce \(O(N^2)\) | Long sequences (DNA, audio) |
#
# - For each, include a **“quick‑look” box** summarizing the change and a link to the original paper.
#
# ---
#
# ### 8. Practical Implementation Tips
#
# 1. **Memory‑Efficient Attention** – Use `torch.nn.functional.scaled_dot_product_attention` (PyTorch 2.0) or FlashAttention.
# 2. **Checkpointing** – Trade compute for memory on deep stacks.
# 3. **Layer‑wise LR decay** – Lower LR for lower layers when fine‑tuning.
# 4. **Debugging** – Visualize attention heads; watch for “attention collapse”.
# 5. **Reproducibility** – Seed everything, log hyper‑parameters with tools like Weights & Biases.
#
# ---
#
# ### 9. Real‑World Applications
#
# - **NLP**: Machine translation, summarization, question answering, code generation.
# - **Vision**: Image classification, object detection (DETR), video understanding.
# - **Audio**: Speech recognition (Speech‑Transformer), music generation.
# - **Multimodal**: CLIP (image‑text), Flamingo (few‑shot vision‑language).
# - **Scientific**: Protein folding (AlphaFold), drug discovery (MolTransformer).
#
# - Include a **case‑study sidebar** (e.g., “How GPT‑4 uses a massive decoder‑only transformer”).
#
# ---
#
# ### 10. Current Challenges & Research Frontiers
#
# - **Quadratic attention cost** → Sparse/linear attention research.
# - **Interpretability** → Probing attention patterns, attribution methods.
# - **Bias & Fairness** → Token‑level biases, mitigation strategies.
# - **Energy consumption** → Model pruning, distillation, quantization.
# - **Continual Learning** → Avoiding catastrophic forgetting in large LMs.
#
# - End with a **“What’s next?”** bullet list (e.g., foundation models, emergent abilities, hybrid architectures).
#
# ---
#
# ### 11. Conclusion
#
# - Recap the **core ideas**: self‑attention, multi‑head, encoder‑decoder.
# - Emphasize **why the transformer matters** beyond NLP.
# - Call‑to‑action: encourage readers to experiment with a minimal transformer implementation (link to a Colab notebook).
#
# ---
#
# ### 12. References & Further Reading
#
# | Category | Paper / Resource | Link |
# |----------|------------------|------|
# | Original | “Attention Is All You Need” (Vaswani et al., 2017) | arXiv:1706.03762 |
# | BERT | “BERT: Pre‑training of Deep Bidirectional Transformers for Language Understanding” | arXiv:1810.04805 |
# | GPT | “Improving Language Understanding by Generative Pre‑training” | OpenAI blog |
# | Efficient Attention | “Performers: Linear Attention” | arXiv:2009.14794 |
# | Vision | “An Image is Worth 16×16 Words: Transformers for Image Recognition at Scale” (ViT) | arXiv:2010.11929 |
# | Tools | Hugging Face Transformers docs | https://huggingface.co/transformers |
# | Visualization | “bertviz” library | https://github.com/jessevig/bertviz |
#
# - Add a **“Suggested Reading Path”** for beginners → intermediate → advanced.
#
# ---
#
# ### 13. Appendices (Optional)
#
# - **Appendix A:** Full PyTorch implementation of a tiny transformer (≤ 200 LOC).
# - **Appendix B:** Glossary of key terms (e.g., *head*, *mask*, *layer norm*).
# - **Appendix C:** FAQ – “Do I need both encoder & decoder?”, “When to use a decoder‑only model?”, etc.
#
# ---
#
# ## Formatting & Visual Aids (Tips for the Writer)
#
# | Section | Suggested Visual |
# |--------|------------------|
# | Architecture Overview | Block diagram of encoder‑decoder stacks with arrows for attention flow |
# | Scaled Dot‑Product | 2‑D plot of query/key vectors + heat‑map of softmax scores |
# | Multi‑Head | Side‑by‑side heads showing different attention patterns |
# | Positional Encoding | Sinusoid wave plot vs. learned vectors |
# | Variants Table | Timeline infographic of major transformer milestones |
# | Application Cases | Screenshots of real‑world products (e.g., ChatGPT UI, CLIP image retrieval) |
# | Challenges | Bar chart of FLOPs vs. sequence length for different attention approximations |
#
# ---
#
# ### Final Thought
# End the blog with a **personal note**: why you (the author) find transformers fascinating, and invite readers to share their own experiments in the comments. This encourages community engagement and positions the post as a living resource.

# %%
print(final_state['content'])
# Out:
# # **Demystifying the Transformer Architecture**
# *Your guide from “what is a transformer?” to “how to build one and push the frontier.”*
#
# ---
#
# ## 1. Introduction
#
# ### Hook – Why Transformers dominate NLP (and everything else)
#
# If you’ve ever typed a query into ChatGPT, asked a voice assistant for a recipe, or used Google Translate, you’ve already interacted with a **transformer**. Since the seminal *“Attention Is All You Need”* paper (Vaswani et al., 2017) the transformer has become the de‑facto standard for natural‑language processing, and its influence now reaches vision, audio, biology, and even reinforcement learning.
#
# ### Brief History
#
# | Year | Milestone | Impact |
# |------|-----------|--------|
# | **2017** | *Attention Is All You Need* (Vaswani et al.) | Introduced the self‑attention‑only architecture, replacing RNNs/CNNs. |
# | **2018** | **BERT** (Devlin et al.) | First large‑scale pre‑training with a bidirectional encoder. |
# | **2019** | **GPT‑2** (Radford et al.) | Demonstrated the power of decoder‑only, autoregressive LMs. |
# | **2020** | **Vision Transformer (ViT)** (Dosovitskiy et al.) | Showed transformers work on raw image patches. |
# | **2021‑2023** | **Scaling era** – GPT‑3, PaLM, LLaMA, etc. | Billions‑to‑trillions of parameters, emergent abilities. |
# | **2024‑present** | **Sparse & Mixture‑of‑Experts**, **Efficient Attention**, **Multimodal foundation models** | Pushing limits of size, speed, and modality‑fusion. |
#
# ### What You’ll Learn
#
# 1. The **core building blocks** (self‑attention, multi‑head, feed‑forward, etc.) and the intuition behind each.
# 2. A **step‑by‑step walk‑through** of a single transformer layer, with pseudo‑code.
# 3. How **positional encodings** give the model a sense of order.
# 4. Practical **training tricks** that make huge models converge.
# 5. A quick tour of **major variants** (BERT, GPT, ViT, etc.) and when to use them.
# 6. Tips for **implementation, debugging, and scaling**.
# 7. Current **research challenges** and where the field is heading.
#
# ---
#
# ## 2. Foundations: Why We Needed Transformers
#
# | Problem | Traditional Solution | Limitations |
# |---------|----------------------|-------------|
# | **Sequential processing** (RNNs/LSTMs) | Recurrence + hidden state | Vanishing/exploding gradients, hard to parallelize, limited receptive field. |
# | **Fixed‑size context windows** | Convolutional nets (CNNs) | Local receptive fields → struggle with long‑range dependencies. |
# | **Long‑range dependencies** | Hand‑crafted features (e.g., n‑grams, syntax trees) | Poor scalability, brittle to domain shift. |
#
# ### The Key Insight
#
# > **Self‑attention** lets every token directly attend to every other token in a single layer, providing a *global* view without recurrence or convolution. This simple idea unlocks massive parallelism and makes it feasible to train models with billions of parameters.
#
# ---
#
# ## 3. Core Building Blocks
#
# ### 3.1. Input Representation
#
# | Step | What Happens | Why It Matters |
# |------|--------------|----------------|
# | **Tokenization** | WordPiece, BPE, or SentencePiece split raw text into sub‑word units. | Handles out‑of‑vocabulary words and balances vocabulary size vs. sequence length. |
# | **Embedding Lookup** | Each token index → dense vector → **\(X \in \mathbb{R}^{N \times d_{\text{model}}}\)** where *N* = sequence length. | Provides a learnable continuous representation. |
# | **Positional Encoding** | Add a vector that encodes token position (sinusoidal or learned). | Transformers are permutation‑invariant; positional info restores order. |
#
# > **Tip:** For multilingual models, use a **shared sub‑word vocab** (e.g., SentencePiece) to keep the embedding matrix compact.
#
# ---
#
# ### 3.2. Scaled Dot‑Product Attention
#
# \[
# \text{Attention}(Q,K,V)=\underbrace{\text{softmax}\!\Big(\frac{QK^\top}{\sqrt{d_k}}\Big)}_{\text{attention weights}}V
# \]
#
# * **\(Q\)** (queries), **\(K\)** (keys), **\(V\)** (values) are linear projections of the same (or different) source.
# * The **\(\sqrt{d_k}\)** scaling prevents the softmax from saturating when the dimensionality grows.
#
# **Intuition:**
# - *Query* = “What am I looking for?”
# - *Key* = “What does each token contain?”
# - *Value* = “What information should I retrieve?”
#
# A heat‑map of the softmax scores for the sentence *“The cat sat on the mat.”* often shows strong diagonal patterns (tokens attending to themselves) plus a few off‑diagonal spikes (e.g., “cat” ↔ “sat”).
#
# ---
#
# ### 3.3. Multi‑Head Attention
#
# Instead of a single attention subspace, we **split** the model dimension into *h* heads:
#
# 1. **Linear projections** → \(Q_i, K_i, V_i\) for head *i* (each of size \(d_k = d_{\text{model}}/h\)).
# 2. Compute **scaled dot‑product attention** per head.
# 3. **Concatenate** the *h* outputs → \(\mathbb{R}^{N \times d_{\text{model}}}\).
# 4. Final linear projection \(\mathbf{W}^O\) mixes the heads.
#
# **Benefits:**
# - Captures **different relational patterns** simultaneously (syntactic vs. semantic).
# - Provides a cheap form of **model ensemble** within a single layer.
#
# ---
#
# ### 3.4. Position‑wise Feed‑Forward Networks (FFN)
#
# Applied **independently** to each token (identical weights across positions):
#
# \[
# \text{FFN}(x)=\max(0, xW_1 + b_1)W_2 + b_2
# \]
#
# *Typical settings:* \(d_{\text{model}} = 768\), inner dimension \(d_{\text{ff}} = 3072\).
# *Activation:* ReLU or GELU (the latter works better for very deep models).
#
# ---
#
# ### 3.5. Residual Connections & Layer Normalization
#
# Each sub‑layer (attention, FFN) is wrapped as **Add & Norm**:
#
# \[
# \text{output}= \text{LayerNorm}(x + \text{Sublayer}(x))
# \]
#
# *Why?*
# - **Residuals** help gradients flow through dozens of layers.
# - **LayerNorm** stabilizes the hidden‑state distribution, allowing higher learning rates.
#
# ---
#
# ### 3.6. Encoder vs. Decoder Stacks
#
# | Feature | Encoder | Decoder |
# |---------|---------|---------|
# | **Self‑attention** | Full (tokens can see all positions) | **Masked** self‑attention (causal mask) → prevents looking ahead. |
# | **Cross‑attention** | — | **Encoder‑decoder attention** (queries from decoder, keys/values from encoder). |
# | **Feed‑forward** | Same as decoder | Same as encoder |
# | **Purpose** | Produce contextualized representations of the input. | Autoregressively generate output tokens (e.g., translation). |
#
# > **Diagram suggestion:** A side‑by‑side schematic with arrows: encoder → decoder, and a triangular mask on the decoder’s self‑attention.
#
# ---
#
# ## 4. Detailed Walkthrough of a Single Transformer Layer
#
# Below is the canonical order of operations for **one encoder layer** (decoder adds the extra masked‑attention and cross‑attention blocks).
#
# | Step | Operation | Shapes (assuming batch *B*) |
# |------|-----------|------------------------------|
# | 1️⃣ | **Multi‑Head Self‑Attention**: compute \(Q,K,V = XW^Q, XW^K, XW^V\) → attention → \(\text{Attn}(X)\) | \((B,N,d_{\text{model}})\) |
# | 2️⃣ | **Add & Norm**: \(X_1 = \text{LayerNorm}(X + \text{Attn}(X))\) | \((B,N,d_{\text{model}})\) |
# | 3️⃣ | **Feed‑Forward**: \(\text{FFN}(X_1)\) | \((B,N,d_{\text{model}})\) |
# | 4️⃣ | **Add & Norm**: \(Y = \text{LayerNorm}(X_1 + \text{FFN}(X_1))\) | \((B,N,d_{\text{model}})\) |
# | 5️⃣ | **Output** → next layer (or decoder) | — |
#
# ### PyTorch‑style Pseudo‑code
#
# ```python
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
#
# class TransformerEncoderLayer(nn.Module):
#     def __init__(self, d_model=768, nhead=12, dim_ff=3072,
#                  dropout=0.1, activation='gelu'):
#         super().__init__()
#         self.self_attn = nn.MultiheadAttention(d_model, nhead,
#                                                dropout=dropout,
#                                                batch_first=True)
#
#         self.linear1 = nn.Linear(d_model, dim_ff)
#         self.linear2 = nn.Linear(dim_ff, d_model)
#
#         self.norm1 = nn.LayerNorm(d_model)
#         self.norm2 = nn.LayerNorm(d_model)
#
#         self.dropout = nn.Dropout(dropout)
#         self.activation = (F.gelu if activation == 'gelu'
#                            else F.relu)
#
#     def forward(self, src, src_mask=None, src_key_padding_mask=None):
#         # 1️⃣ Multi‑head self‑attention
#         attn_output, _ = self.self_attn(src, src, src,
#                                         attn_mask=src_mask,
#                                         key_padding_mask=src_key_padding_mask)
#         # 2️⃣ Add & Norm
#         src = self.norm1(src + self.dropout(attn_output))
#
#         # 3️⃣ Feed‑forward
#         ff = self.linear2(self.dropout(self.activation(self.linear1(src))))
#
#         # 4️⃣ Add & Norm
#         out = self.norm2(src + self.dropout(ff))
#         return out
# ```
#
# *The decoder layer just adds two more sub‑layers (`masked_self_attn` and `enc_dec_attn`).*
#
# ---
#
# ## 5. Positional Encoding Deep Dive
#
# ### 5.1. Sinusoidal Positional Encodings
#
# \[
# \begin{aligned}
# \text{PE}_{(pos,2i)}   &= \sin\!\Big(\frac{pos}{10000^{2i/d_{\text{model}}}}\Big) \\
# \text{PE}_{(pos,2i+1)} &= \cos\!\Big(\frac{pos}{10000^{2i/d_{\text{model}}}}\Big)
# \end{aligned}
# \]
#
# *Properties:*
# - **Deterministic** – no extra parameters to learn.
# - **Extrapolatable** – can handle longer sequences than seen during training (the sinusoid continues).
#
# ### 5.2. Learned Positional Embeddings
#
# A simple lookup table \(\mathbf{P} \in \mathbb{R}^{\text{max\_len}\times d_{\text{model}}}\).
#
# *When to prefer:*
# - Vision Transformers (ViT) – patches have a fixed grid, so learning the positional bias improves performance.
# - Extremely long sequences where sinusoidal may not capture complex positional patterns.
#
# ### 5.3. Experiment: “With vs. Without Positional Info”
#
# ```python
# # Tiny transformer on a synthetic copy task
# model = TinyTransformer(use_positional=False)   # no position info
# loss_no_pos = train(model)                      # ~> fails to learn ordering
#
# model = TinyTransformer(use_positional=True)    # sinusoidal
# loss_pos = train(model)                         # converges quickly
# ```
#
# *Result:* The model without positional encodings can only learn **bag‑of‑words** statistics; it never learns to output “the cat sat” in the correct order.
#
# ---
#
# ## 6. Training the Transformer
#
# | Aspect | Typical Choices | Why It Matters |
# |--------|----------------|----------------|
# | **Optimizer** | **AdamW** (β₁=0.9, β₂=0.98, ε=1e‑9) | Decouples weight decay, works well with large LR warm‑up. |
# | **Learning‑rate schedule** | **Warm‑up + inverse‑sqrt decay**: \(\text{LR}_t = \text{LR}_0 \cdot \min(t^{-0.5}, t\cdot \text{warmup}^{-1.5})\) | Prevents divergence in early steps, smooths later convergence. |
# | **Regularization** | Dropout 0.1 (attention & FFN), **label smoothing** 0.1 | Reduces over‑fitting, improves calibration. |
# | **Batch size & mixed‑precision** | 32‑64 GB GPUs, **FP16** (or bfloat16) | Cuts memory by ~2×, speeds up matmul kernels. |
# | **Gradient clipping** | Norm ≤ 1.0 (global) | Stops exploding gradients in deep stacks. |
# | **Weight initialization** | **Xavier** (a.k.a. Glorot) for linear layers, **zero** bias for attention output projection | Provides stable variance across layers. |
#
# ### Skeleton of a Training Loop (
